# %% [markdown]
#  # Medicine Dataset of Bangladesh in JSON format_

# %% [markdown]
# #                         Allopathic in JSON format (35015 Records)

# %%
import requests
import json

url = "https://dgdagov.info/administrator/components/com_jcode/source/serverProcessing.php"

payload = "sEcho=1&iColumns=9&sColumns=&iDisplayStart=0&iDisplayLength=35015&mDataProp_0=0&mDataProp_1=1&mDataProp_2=2&mDataProp_3=3&mDataProp_4=4&mDataProp_5=5&mDataProp_6=6&mDataProp_7=7&mDataProp_8=8&sSearch=&bRegex=false&sSearch_0=&bRegex_0=false&bSearchable_0=true&sSearch_1=&bRegex_1=false&bSearchable_1=true&sSearch_2=&bRegex_2=false&bSearchable_2=true&sSearch_3=&bRegex_3=false&bSearchable_3=true&sSearch_4=&bRegex_4=false&bSearchable_4=true&sSearch_5=&bRegex_5=false&bSearchable_5=true&sSearch_6=&bRegex_6=false&bSearchable_6=true&sSearch_7=&bRegex_7=false&bSearchable_7=true&sSearch_8=&bRegex_8=false&bSearchable_8=true&iSortCol_0=1&sSortDir_0=asc&iSortingCols=1&bSortable_0=false&bSortable_1=true&bSortable_2=true&bSortable_3=true&bSortable_4=true&bSortable_5=true&bSortable_6=false&bSortable_7=true&bSortable_8=false&action=getDrugCompanyDatabaseData&FilterAll=4&FilterItem="
headers = {
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.9',
    'Connection': 'keep-alive',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': '64b89d05a4a7cf540e8cd068c2904eaf=77b154f3da337a3d3a4c2fcc3fa622fe',
    'Origin': 'https://dgdagov.info',
    'Referer': 'https://dgdagov.info/index.php/registered-products/allopathic',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("POST", url, headers=headers, data=payload)

if response.status_code == 200:
    try:

        json_data = response.json()

    
        headers_data = [
    "#SL",
    "Name of the Manufacturer",
    "Brand Name",
    "Generic Name",
    "Strength",
    "Dosages Description",
    "Retail Price (Tk.)",
    "Use For",
    "DAR"
]


        formatted_data = json_data.get('aaData', [])

    
        result_json = []
        for row in formatted_data:
            result_json.append(dict(zip(headers_data, row)))
            
        

  
        result_json_str = json.dumps(result_json, indent=2)
    
 
        for row in result_json[:3]:
            print(json.dumps(row, indent=2))

        with open('Alopathic.json', 'w') as json_file:
            json_file.write(result_json_str)

        print("Data stored in 'output.json'")
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {
#   "#SL": "1",
#   "Name of the Manufacturer": "ACI HealthCare Limited",
#   "Brand Name": "Nimocon 500",
#   "Generic Name": "Azithromycin",
#   "Strength": "500 mg",
#   "Dosages Description": "Tablet",
#   "Retail Price (Tk.)": "0",
#   "Use For": "Human",
#   "DAR": "394-0001-023"
# }
# {
#   "#SL": "2",
#   "Name of the Manufacturer": "ACI HealthCare Limited",
#   "Brand Name": "Adbon",
#   "Generic Name": "Calcium + Vitamin D3",
#   "Strength": "500 mg + 200 IU",
#   "Dosages Description": "Tablet",
#   "Retail Price (Tk.)": "0",
#   "Use For": "Human",
#   "DAR": "394-0002-062"
# }
# {
#   "#SL": "3",
#   "Name of the Manufacturer": "ACI HealthCare Limited",
#   "Brand Name": "Opental 50",
#   "Generic Name": "Tramadol Hydrochloride",
#   "Strength": "50 mg",
#   "Dosages Description": "Tablet",
#   "Retail Price (Tk.)": "0",
#   "Use For": "Human",
#   "DAR": "394-0003-065"
# }
# Data stored in 'output.json'

# %% [markdown]
# # Ayurvedic data in JSON format (5138 Records)

# %%
import http.client
import json
import re



conn = http.client.HTTPConnection("dgdagov.info")

payload = "sEcho=3&iColumns=6&sColumns=&sSearch=&sSearch_0=&sSearch_1=&sSearch_2=&sSearch_3=&sSearch_4=&sSearch_5=&FilterItem=&iDisplayStart=0&iDisplayLength=5138&mDataProp_0=0&mDataProp_1=1&mDataProp_2=2&mDataProp_3=3&mDataProp_4=4&mDataProp_5=5&bRegex=false&bRegex_0=false&bSearchable_0=true&bRegex_1=false&bSearchable_1=true&bRegex_2=false&bSearchable_2=true&bRegex_3=false&bSearchable_3=true&bRegex_4=false&bSearchable_4=true&bRegex_5=false&bSearchable_5=true&iSortCol_0=2&sSortDir_0=asc&iSortingCols=1&bSortable_0=false&bSortable_1=true&bSortable_2=true&bSortable_3=true&bSortable_4=true&bSortable_5=false&action=getDrugOthersCompanyDatabaseData&FilterAll=4&ManufacturerCategory=A"
headers = {
    'Accept': "application/json, text/javascript, */*; q=0.01",
    'Accept-Language': "en-US,en;q=0.9,bn;q=0.8",
    'Cache-Control': "no-cache",
    'Connection': "keep-alive",
    'Content-Type': "application/x-www-form-urlencoded; charset=UTF-8",
    'Cookie': "64b89d05a4a7cf540e8cd068c2904eaf=689e4bf4517fe1988f4a1b5ac2cb2856",
    'Origin': "http://dgdagov.info",
    'Pragma': "no-cache",
    'Referer': "http://dgdagov.info/index.php/registered-products/ayurvedic",
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    'X-Requested-With': "XMLHttpRequest"
}

try:
    conn.request("POST", "/administrator/components/com_jcode/source/serverProcessing.php", payload, headers)

    res = conn.getresponse()
    data = res.read().decode("utf-8")


    if res.status == 200:
        try:
         

           
            cleaned_data = re.sub(r'\\[^\\"\/bfnrtu]', '', data)
            
          
            json_data = json.loads(cleaned_data)

           
            headers_data = ["SL", "Name of the Pharmaceutical", "Brand Name", "Dosages", "Generic Name and Strength", "DAR"]

           
            formatted_data = json_data.get('aaData', [])

          
            result_json = []
            for row in formatted_data:
                result_json.append(dict(zip(headers_data, row)))
                
            for row in result_json[:3]:
                print(json.dumps(row, indent=2))

           
            parsed_file_path = f'{kaggle_working_dir}/Ayurvedic.json'
            with open(parsed_file_path, 'w') as json_file:
                json.dump(result_json, json_file, indent=2)
            print(f"Parsed JSON Data saved to: {parsed_file_path}")

#            

        except json.JSONDecodeError as json_error:
            print(f"JSON decoding error: {json_error}")

    else:
        print(f"Error: {res.status}, {res.reason}")

except Exception as e:
    print(f"An error occurred: {e}")

finally:
    conn.close()
# Out:
# {
#   "SL": "1",
#   "Name of the Pharmaceutical": "A B Laboratories (Ayurvedic)",
#   "Brand Name": "Gasmo",
#   "Dosages": "Capsule",
#   "Generic Name and Strength": "Amlapittantak Churna",
#   "DAR": "AY-46-A-034"
# }
# {
#   "SL": "2",
#   "Name of the Pharmaceutical": "A B Laboratories (Ayurvedic)",
#   "Brand Name": "Espec",
#   "Dosages": "Capsule",
#   "Generic Name and Strength": "Echinacea",
#   "DAR": "AY-46-A-035"
# }
# {
#   "SL": "3",
#   "Name of the Pharmaceutical": "A B Laboratories (Ayurvedic)",
#   "Brand Name": "Ruchirise",
#   "Dosages": "Capsule",
#   "Generic Name and Strength": "Ginger",
#   "DAR": "AY-46-A-036"
# }
# An error occurred: name 'kaggle_working_dir' is not defined

# %% [markdown]
# # Unani in JSON format (8263 Records)

# %%
import http.client
import json
import re



conn = http.client.HTTPConnection("dgdagov.info")

payload = "sEcho=1&iColumns=6&sColumns=&iDisplayStart=0&iDisplayLength=8263&mDataProp_0=0&mDataProp_1=1&mDataProp_2=2&mDataProp_3=3&mDataProp_4=4&mDataProp_5=5&sSearch=&bRegex=false&sSearch_0=&bRegex_0=false&bSearchable_0=true&sSearch_1=&bRegex_1=false&bSearchable_1=true&sSearch_2=&bRegex_2=false&bSearchable_2=true&sSearch_3=&bRegex_3=false&bSearchable_3=true&sSearch_4=&bRegex_4=false&bSearchable_4=true&sSearch_5=&bRegex_5=false&bSearchable_5=true&iSortCol_0=2&sSortDir_0=asc&iSortingCols=1&bSortable_0=false&bSortable_1=true&bSortable_2=true&bSortable_3=true&bSortable_4=true&bSortable_5=false&action=getDrugOthersCompanyDatabaseData&FilterAll=4&FilterItem=&ManufacturerCategory=U"
headers = {
  'Accept': 'application/json, text/javascript, */*; q=0.01',
  'Accept-Language': 'en-US,en;q=0.9,bn;q=0.8',
  'Cache-Control': 'no-cache',
  'Connection': 'keep-alive',
  'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
  'Cookie': '64b89d05a4a7cf540e8cd068c2904eaf=689e4bf4517fe1988f4a1b5ac2cb2856; 64b89d05a4a7cf540e8cd068c2904eaf=910e299a2aed710300daa6091b3caacc',
  'Origin': 'http://dgdagov.info',
  'Pragma': 'no-cache',
  'Referer': 'http://dgdagov.info/index.php/registered-products/unani',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
  'X-Requested-With': 'XMLHttpRequest'
}

try:
    conn.request("POST", "/administrator/components/com_jcode/source/serverProcessing.php", payload, headers)

    res = conn.getresponse()
    data = res.read().decode("utf-8")



    if res.status == 200:
        try:
         

     
            cleaned_data = re.sub(r'\\[^\\"\/bfnrtu]', '', data)
            
          
            json_data = json.loads(cleaned_data)

        
            headers_data = ["SL", "Name of the Pharmaceutical", "Brand Name", "Dosages", "Generic Name and Strength", "DAR"]

      
            formatted_data = json_data.get('aaData', [])

        
            result_json = []
            for row in formatted_data:
                result_json.append(dict(zip(headers_data, row)))
            result_json_str = json.dumps(result_json, indent=2)
            
            for row in result_json[:3]:
                print(json.dumps(row, indent=2))

                
            with open('Unani.json', 'w') as json_file:
                json_file.write(result_json_str)

      

        except json.JSONDecodeError as json_error:
            print(f"JSON decoding error: {json_error}")

    else:
        print(f"Error: {res.status}, {res.reason}")

except Exception as e:
    print(f"An error occurred: {e}")

finally:
    conn.close()
# Out:
# {
#   "SL": "1",
#   "Name of the Pharmaceutical": "4-S Labaratories (Unani)",
#   "Brand Name": "Harbikof",
#   "Dosages": "Liquid",
#   "Generic Name and Strength": "Sharbat Tulsi",
#   "DAR": "U-20-A-001"
# }
# {
#   "SL": "2",
#   "Name of the Pharmaceutical": "4-S Labaratories (Unani)",
#   "Brand Name": "Hazmi-S",
#   "Dosages": "Liquid",
#   "Generic Name and Strength": "Sharbat Hazmina",
#   "DAR": "U-20-A-002"
# }
# {
#   "SL": "3",
#   "Name of the Pharmaceutical": "4-S Labaratories (Unani)",
#   "Brand Name": "Leucobin",
#   "Dosages": "Liquid",
#   "Generic Name and Strength": "Sharbat Niswan",
#   "DAR": "U-20-A-003"
# }

# %% [markdown]
# # Herbal in Json format (858 Records)

# %%
import http.client
import json
import re




conn = http.client.HTTPConnection("dgdagov.info")

payload = "sEcho=1&iColumns=6&sColumns=&iDisplayStart=0&iDisplayLength=858&mDataProp_0=0&mDataProp_1=1&mDataProp_2=2&mDataProp_3=3&mDataProp_4=4&mDataProp_5=5&sSearch=&bRegex=false&sSearch_0=&bRegex_0=false&bSearchable_0=true&sSearch_1=&bRegex_1=false&bSearchable_1=true&sSearch_2=&bRegex_2=false&bSearchable_2=true&sSearch_3=&bRegex_3=false&bSearchable_3=true&sSearch_4=&bRegex_4=false&bSearchable_4=true&sSearch_5=&bRegex_5=false&bSearchable_5=true&iSortCol_0=2&sSortDir_0=asc&iSortingCols=1&bSortable_0=false&bSortable_1=true&bSortable_2=true&bSortable_3=true&bSortable_4=true&bSortable_5=false&action=getDrugOthersCompanyDatabaseData&FilterAll=4&FilterItem=&ManufacturerCategory=H"
headers = {
  'Accept': 'application/json, text/javascript, */*; q=0.01',
  'Accept-Language': 'en-US,en;q=0.9,bn;q=0.8',
  'Cache-Control': 'no-cache',
  'Connection': 'keep-alive',
  'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
  'Cookie': '64b89d05a4a7cf540e8cd068c2904eaf=689e4bf4517fe1988f4a1b5ac2cb2856; 64b89d05a4a7cf540e8cd068c2904eaf=910e299a2aed710300daa6091b3caacc',
  'Origin': 'http://dgdagov.info',
  'Pragma': 'no-cache',
  'Referer': 'http://dgdagov.info/index.php/registered-products/herbal',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
  'X-Requested-With': 'XMLHttpRequest'
}


try:
    conn.request("POST", "/administrator/components/com_jcode/source/serverProcessing.php", payload, headers)

    res = conn.getresponse()
    data = res.read().decode("utf-8")

    print("Response Status:", res.status)
    print("Response Reason:", res.reason)
#     print("Raw Response Data:", data)

    if res.status == 200:
        try:
         

       
            cleaned_data = re.sub(r'\\[^\\"\/bfnrtu]', '', data)
  
            json_data = json.loads(cleaned_data)

        
            headers_data = ["SL", "Name of the Pharmaceutical", "Brand Name", "Dosages", "Generic Name and Strength", "DAR"]

   
            formatted_data = json_data.get('aaData', [])

     
            result_json = []
            for row in formatted_data:
                result_json.append(dict(zip(headers_data, row)))

            result_json_str = json.dumps(result_json, indent=2)
            
             
            for row in result_json[:3]:
                print(json.dumps(row, indent=2))

                
            with open('Herbal.json', 'w') as json_file:
                json_file.write(result_json_str)


        except json.JSONDecodeError as json_error:
            print(f"JSON decoding error: {json_error}")

    else:
        print(f"Error: {res.status}, {res.reason}")

except Exception as e:
    print(f"An error occurred: {e}")

finally:
    conn.close()
# Out:
# Response Status: 200
# Response Reason: OK
# {
#   "SL": "1",
#   "Name of the Pharmaceutical": "Acme Labortories Ltd. (Herbal Division)",
#   "Brand Name": "Megajoy 75 Tablet",
#   "Dosages": "Tablet",
#   "Generic Name and Strength": "Yohimbine Hydrochloride",
#   "DAR": "002-0011-94"
# }
# {
#   "SL": "2",
#   "Name of the Pharmaceutical": "Acme Labortories Ltd. (Herbal Division)",
#   "Brand Name": "Orthogen",
#   "Dosages": "Tablet",
#   "Generic Name and Strength": "Boron + Boswellia Serrata Extract + Glucosamine Sulfate Potassium Chloride + Undenatured Type II Collagen",
#   "DAR": "002-027-94"
# }
# {
#   "SL": "3",
#   "Name of the Pharmaceutical": "Acme Labortories Ltd. (Herbal Division)",
#   "Brand Name": "Disugar",
#   "Dosages": "Tablet",
#   "Generic Name and Strength": "Rebaudioside A",
#   "DAR": "002-028-94"
# }

# %% [markdown]
# # Homeopathic_and_Biochemic in Json Format (2481 Records)

# %%
import http.client
import json
import re




conn = http.client.HTTPConnection("dgdagov.info")

payload = "sEcho=1&iColumns=6&sColumns=&iDisplayStart=0&iDisplayLength=2481&mDataProp_0=0&mDataProp_1=1&mDataProp_2=2&mDataProp_3=3&mDataProp_4=4&mDataProp_5=5&sSearch=&bRegex=false&sSearch_0=&bRegex_0=false&bSearchable_0=true&sSearch_1=&bRegex_1=false&bSearchable_1=true&sSearch_2=&bRegex_2=false&bSearchable_2=true&sSearch_3=&bRegex_3=false&bSearchable_3=true&sSearch_4=&bRegex_4=false&bSearchable_4=true&sSearch_5=&bRegex_5=false&bSearchable_5=true&iSortCol_0=2&sSortDir_0=asc&iSortingCols=1&bSortable_0=false&bSortable_1=true&bSortable_2=true&bSortable_3=true&bSortable_4=true&bSortable_5=false&action=getDrugOthersCompanyDatabaseData&FilterAll=4&FilterItem=&ManufacturerCategory=B"
headers = {
  'Accept': 'application/json, text/javascript, */*; q=0.01',
  'Accept-Language': 'en-US,en;q=0.9,bn;q=0.8',
  'Cache-Control': 'no-cache',
  'Connection': 'keep-alive',
  'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
  'Cookie': '64b89d05a4a7cf540e8cd068c2904eaf=689e4bf4517fe1988f4a1b5ac2cb2856; 64b89d05a4a7cf540e8cd068c2904eaf=910e299a2aed710300daa6091b3caacc',
  'Origin': 'http://dgdagov.info',
  'Pragma': 'no-cache',
  'Referer': 'http://dgdagov.info/index.php/registered-products/homeopathic-and-biochemic',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
  'X-Requested-With': 'XMLHttpRequest'
}
try:
    conn.request("POST", "/administrator/components/com_jcode/source/serverProcessing.php", payload, headers)

    res = conn.getresponse()
    data = res.read().decode("utf-8")



    if res.status == 200:
        try:
         

    
            cleaned_data = re.sub(r'\\[^\\"\/bfnrtu]', '', data)
            
         
            json_data = json.loads(cleaned_data)

       
            headers_data = ["SL", "Name of the Pharmaceutical", "Brand Name", "Dosages", "Generic Name and Strength", "DAR"]

   
            formatted_data = json_data.get('aaData', [])

         
            result_json = []
            for row in formatted_data:
                result_json.append(dict(zip(headers_data, row)))

            result_json_str = json.dumps(result_json, indent=2)
            
            
            for row in result_json[:3]:
                print(json.dumps(row, indent=2))

        
            with open('Homeopathic_and_Biochemic.json', 'w') as json_file:
                json_file.write(result_json_str)



        except json.JSONDecodeError as json_error:
            print(f"JSON decoding error: {json_error}")

    else:
        print(f"Error: {res.status}, {res.reason}")

except Exception as e:
    print(f"An error occurred: {e}")

finally:
    conn.close()
# Out:
# {
#   "SL": "1",
#   "Name of the Pharmaceutical": "Alif Hoeomo Laboratories",
#   "Brand Name": "Andrographis Peniculata",
#   "Dosages": "Liquid",
#   "Generic Name and Strength": "Andrographis Paniculata",
#   "DAR": "H-66-A-1"
# }
# {
#   "SL": "2",
#   "Name of the Pharmaceutical": "Alif Hoeomo Laboratories",
#   "Brand Name": "Hydratis Can.",
#   "Dosages": "Liquid",
#   "Generic Name and Strength": "Hydrastis Can \u00d8",
#   "DAR": "H-66-A-2"
# }
# {
#   "SL": "3",
#   "Name of the Pharmaceutical": "Alif Hoeomo Laboratories",
#   "Brand Name": "Jonosia Asoka",
#   "Dosages": "Liquid",
#   "Generic Name and Strength": "Jonosia Ashoka \u00d8",
#   "DAR": "H-66-A-3"
# }
